# %%
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
raw_dir = '../data/downloaded_raw'
out_dir = '../data/processed_dat'

sorted(os.listdir(raw_dir))
# Out:
# ['README.md',
#  'agegroup_grooms_brides.csv',
#  'agegroup_grooms_brides.ods',
#  'death_rate_agespecific.csv',
#  'death_rate_agespecific_cleaned.csv',
#  'demographic_ethnicity.csv',
#  'input_birth_fertility_rates_sin_1961-2018.csv',
#  'input_birth_fertility_rates_sin_1961-2018_cleaned.csv',
#  'input_birth_number_by_age_1980-2018.csv',
#  'input_birth_number_by_order_sin_1967-2018.csv',
#  'input_lifetable_sin_2003-2017.csv',
#  'input_marriage_rates_sin_1980-2017.csv',
#  'input_marriage_rates_sin_1980-2017_v2.csv',
#  'input_proportion_singles_age_sin_1980-2018.csv',
#  'input_relationship_status_sin_1980-2018.csv',
#  'inter-ethnic-marriage.csv',
#  'inter-ethnic-marriage.ods',
#  'mariage_by_ethnics.csv']

# %%
df0 = pd.read_csv(os.path.join(raw_dir, 'demographic_ethnicity.csv'))

# %%
df0.head()
# Out:
#   Ethnicity Gender      Variables    1990    1991    1992    1993    1994  \
# 0       All   Both    0 - 4 Years  224049  235519  245751  248771  247022
# 1       All   Both    5 - 9 Years  205628  205807  204724  210359  223824
# 2       All   Both  10 - 14 Years  198476  201155  202170  206698  207032
# 3       All   Both  15 - 19 Years  223305  218157  213331  204085  200002
# 4       All   Both  20 - 24 Years  238987  234658  234805  237867  239253
#
#      1995    1996  ...    2009    2010    2011    2012    2013    2014  \
# 0  248089  245148  ...  197788  194432  188249  186673  183295  181369
# 1  230583  242270  ...  221435  215675  208119  206324  205704  205790
# 2  209583  209322  ...  248628  244302  240536  233320  226244  220796
# 3  199898  202379  ...  262775  263750  260738  258861  255066  247337
# 4  237425  231764  ...  241753  247190  255069  264506  266889  263918
#
#      2015    2016    2017    2018
# 0  183575  187160  187653  185528
# 1  204452  201509  200575  199066
# 2  214388  207495  206253  206530
# 3  242902  239771  232973  226520
# 4  264127  260854  259072  255516
#
# [5 rows x 32 columns]

# %%
df_all = df0[df0['Ethnicity']=='All']
df_all = df_all[df_all['Gender']=='Female']

print(len(df_all))
df_all.head()
# Out:
# 18
#    Ethnicity  Gender      Variables    1990    1991    1992    1993    1994  \
# 36       All  Female    0 - 4 Years  108035  113605  118945  120288  119544
# 37       All  Female    5 - 9 Years   98905   98761   98430  101393  108016
# 38       All  Female  10 - 14 Years   95822   97121   97429   99399   99524
# 39       All  Female  15 - 19 Years  108091  105668  103391   98909   96815
# 40       All  Female  20 - 24 Years  117386  115835  116588  118754  119541
#
#       1995    1996  ...    2009    2010    2011    2012    2013    2014  \
# 36  120057  118773  ...   97089   95542   92364   91749   89775   88841
# 37  111252  117031  ...  107752  105460  102072  101291  101118  101202
# 38  100914  100567  ...  121097  119031  117098  113623  110244  107837
# 39   96777   97998  ...  129321  129747  128159  126755  125077  120823
# 40  118633  115634  ...  120804  123248  126824  131831  132855  131016
#
#       2015    2016    2017    2018
# 36   89723   91482   91612   90612
# 37  100591   99083   98565   97430
# 38  104987  101906  101368  101504
# 39  118615  116860  113473  110418
# 40  130634  128808  127247  125560
#
# [5 rows x 32 columns]

# %%
df_all.columns
# Out:
# Index(['Ethnicity', 'Gender', 'Variables', '1990', '1991', '1992', '1993',
#        '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
#        '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
#        '2012', '2013', '2014', '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
df_all = df_all[['Variables', '1990', '1991', '1992', '1993',
       '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002',
       '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011',
       '2012', '2013', '2014', '2015', '2016', '2017', '2018']]
df_all.head()
# Out:
#         Variables    1990    1991    1992    1993    1994    1995    1996  \
# 36    0 - 4 Years  108035  113605  118945  120288  119544  120057  118773
# 37    5 - 9 Years   98905   98761   98430  101393  108016  111252  117031
# 38  10 - 14 Years   95822   97121   97429   99399   99524  100914  100567
# 39  15 - 19 Years  108091  105668  103391   98909   96815   96777   97998
# 40  20 - 24 Years  117386  115835  116588  118754  119541  118633  115634
#
#       1997    1998  ...    2009    2010    2011    2012    2013    2014  \
# 36  117424  116174  ...   97089   95542   92364   91749   89775   88841
# 37  122799  124652  ...  107752  105460  102072  101291  101118  101202
# 38  100332  103466  ...  121097  119031  117098  113623  110244  107837
# 39   98426  100655  ...  129321  129747  128159  126755  125077  120823
# 40  113188  108725  ...  120804  123248  126824  131831  132855  131016
#
#       2015    2016    2017    2018
# 36   89723   91482   91612   90612
# 37  100591   99083   98565   97430
# 38  104987  101906  101368  101504
# 39  118615  116860  113473  110418
# 40  130634  128808  127247  125560
#
# [5 rows x 30 columns]

# %%
df_all2 = df_all.set_index('Variables')
df_all2.head()
# Out:
#                  1990    1991    1992    1993    1994    1995    1996    1997  \
# Variables
# 0 - 4 Years    108035  113605  118945  120288  119544  120057  118773  117424
# 5 - 9 Years     98905   98761   98430  101393  108016  111252  117031  122799
# 10 - 14 Years   95822   97121   97429   99399   99524  100914  100567  100332
# 15 - 19 Years  108091  105668  103391   98909   96815   96777   97998   98426
# 20 - 24 Years  117386  115835  116588  118754  119541  118633  115634  113188
#
#                  1998    1999  ...    2009    2010    2011    2012    2013  \
# Variables                      ...
# 0 - 4 Years    116174  112306  ...   97089   95542   92364   91749   89775
# 5 - 9 Years    124652  124136  ...  107752  105460  102072  101291  101118
# 10 - 14 Years  103466  110255  ...  121097  119031  117098  113623  110244
# 15 - 19 Years  100655  100823  ...  129321  129747  128159  126755  125077
# 20 - 24 Years  108725  106600  ...  120804  123248  126824  131831  132855
#
#                  2014    2015    2016    2017    2018
# Variables
# 0 - 4 Years     88841   89723   91482   91612   90612
# 5 - 9 Years    101202  100591   99083   98565   97430
# 10 - 14 Years  107837  104987  101906  101368  101504
# 15 - 19 Years  120823  118615  116860  113473  110418
# 20 - 24 Years  131016  130634  128808  127247  125560
#
# [5 rows x 29 columns]

# %% [markdown]
# ## a quick look on the data

# %%
df_all3 = df_all2.T
df_all3.head()
# Out:
# Variables  0 - 4 Years  5 - 9 Years  10 - 14 Years  15 - 19 Years  \
# 1990            108035        98905          95822         108091
# 1991            113605        98761          97121         105668
# 1992            118945        98430          97429         103391
# 1993            120288       101393          99399          98909
# 1994            119544       108016          99524          96815
#
# Variables  20 - 24 Years  25 - 29 Years  30 - 34 Years  35 - 39 Years  \
# 1990              117386         143189         146190         125570
# 1991              115835         143436         149194         132175
# 1992              116588         142504         150733         138410
# 1993              118754         140794         152122         143785
# 1994              119541         137814         153650         148324
#
# Variables  40 - 44 Years  45 - 49 Years  50 - 54 Years  55 - 59 Years  \
# 1990              101611          63647          58570          50192
# 1991              110538          63651          63081          50866
# 1992              113914          72772          66074          50648
# 1993              118404          82292          66814          51944
# 1994              123426          90865          66821          55309
#
# Variables  60 - 64 Years  65 - 69 Years  70 - 74 Years  75 - 79 Years  \
# 1990               41926          30505          24534          18437
# 1991               43353          31561          24855          18597
# 1992               44282          33212          25208          18815
# 1993               45023          35106          25865          18877
# 1994               46282          37394          26345          19110
#
# Variables  80 - 84 Years  85 Years & Over
# 1990               10498             6469
# 1991               11225             6876
# 1992               11956             7378
# 1993               12575             7982
# 1994               12895             8494

# %%
fig, ax = plt.subplots(figsize=(16,12))
for col in df_all3.columns:
    ax.plot([float(a) for a in df_all3.index.tolist()], [float(a) for a in df_all3[col].tolist()], marker='s')
    ax.annotate(col.replace('Years','').replace(' ','').replace('&Over',''), xy=(2018.5, float(df_all3[col].tolist()[-1])), xycoords='data')
    #break
ax.set_xlim([1989, 2020])
ax.axvline(x=1990., ls='--', color='grey')
ax.axvline(x=2000., ls='--', color='grey')
ax.axvline(x=2010., ls='--', color='grey')
ax.axvline(x=1995., ls=':', color='grey')
ax.axvline(x=2005., ls=':', color='grey')
ax.axvline(x=2015., ls=':', color='grey')
#ax.legend()

# %% [markdown]
# ## prepare data
# use 1990, 2000, 2010 as the three input data year, and ~1995, ~2005, ~2015 as the validate year, respectively

# %%
df_all2.head()
# Out:
#                  1990    1991    1992    1993    1994    1995    1996    1997  \
# Variables
# 0 - 4 Years    108035  113605  118945  120288  119544  120057  118773  117424
# 5 - 9 Years     98905   98761   98430  101393  108016  111252  117031  122799
# 10 - 14 Years   95822   97121   97429   99399   99524  100914  100567  100332
# 15 - 19 Years  108091  105668  103391   98909   96815   96777   97998   98426
# 20 - 24 Years  117386  115835  116588  118754  119541  118633  115634  113188
#
#                  1998    1999  ...    2009    2010    2011    2012    2013  \
# Variables                      ...
# 0 - 4 Years    116174  112306  ...   97089   95542   92364   91749   89775
# 5 - 9 Years    124652  124136  ...  107752  105460  102072  101291  101118
# 10 - 14 Years  103466  110255  ...  121097  119031  117098  113623  110244
# 15 - 19 Years  100655  100823  ...  129321  129747  128159  126755  125077
# 20 - 24 Years  108725  106600  ...  120804  123248  126824  131831  132855
#
#                  2014    2015    2016    2017    2018
# Variables
# 0 - 4 Years     88841   89723   91482   91612   90612
# 5 - 9 Years    101202  100591   99083   98565   97430
# 10 - 14 Years  107837  104987  101906  101368  101504
# 15 - 19 Years  120823  118615  116860  113473  110418
# 20 - 24 Years  131016  130634  128808  127247  125560
#
# [5 rows x 29 columns]

# %%
def interpolation(midyears, popsize):
    x_news = []
    y_news = []
    for i in range(18):
        tempx = []
        tempy = []
        if i-1>=0:
            tempx.append(midyears[i-1])
            tempy.append(popsize[i-1])
        tempx.append(midyears[i])
        tempy.append(popsize[i])
        if i+1<=17:
            tempx.append(midyears[i+1])
            tempy.append(popsize[i+1])
        else:
            tempx.append(101)
            tempy.append(0)
            
        z = np.polyfit(tempx, tempy, 1)
        f = np.poly1d(z)
        if i<17:
            x_new = [ float(x) for x in list(range(int(midyears[i]-2), int(midyears[i]+3))) ]
        else:
            x_new = [ float(x) for x in list(range(int(midyears[i]-2), int(midyears[i]+14))) ]
        y_new = f(x_new)
        x_news.extend(x_new)
        y_news.extend(y_new)
    miny = abs(min(y_news))
    y_news = [ y+miny for y in y_news ]
    return x_news, y_news

#def check

# %% [markdown]
# get a look on the interpolation result

# %%
origin_years = ['1990', '2000', '2010']
agyears = [col.replace('Years','').replace(' ','').replace('&Over','-') for col in df_all2.index]
midyears = [ i*5.+2. for i in range(18) ]
midyears_ex = [ i*5.+2. for i in range(-1,21) ]

for oy in origin_years:
    df_temp = df_all2[[oy]]
    #print(df_temp.head())
    popsize =  [ y/5. for y in df_temp[oy].tolist()]
    x_news, y_news = interpolation(midyears, popsize)
    
    fig, ax = plt.subplots()
    ax.plot(midyears, popsize)
    ax.scatter(x_news, y_news, marker='.')
    ax.set_xticks(midyears_ex)
    ax.set_xticklabels(midyears_ex, rotation=90)
    ax.set_title(oy)
    ax.axvline(x=0, ls=':', c='grey')
    ax.axvline(x=100, ls=':', c='grey')
    ax.axhline(y=0, ls='--', c='grey')
    #print(x_news)

# %%
origin_years = ['1990', '2000', '2010']
agyears = [col.replace('Years','').replace(' ','').replace('&Over','-') for col in df_all2.index]
midyears = [ i*5.+2. for i in range(18) ]
midyears_ex = [ i*5.+2. for i in range(-1,21) ]

headers = ['# age distribution (female only) - data processed from SingStat, check docs/data_input_sources.md for references\n', 
'# this data serve for generating fertility_age_prob.dat, not for the current model \n', 
'# columns:\n', 
'#   0=proportion \n', 
'#   1=age\n']

for oy in origin_years:
    outpath = os.path.join(out_dir, 'age_dist_female_y{}.dat'.format(oy))
    df_temp = df_all2[[oy]]
    #print(df_temp.head())
    popsize =  [ y/5. for y in df_temp[oy].tolist()]
    x_news, y_news = interpolation(midyears, popsize)
    ysum = float(sum(y_news))
    y_prop = [ float(y)/ysum for y in y_news ]
    with open(outpath, 'w') as fhand:
        for line in headers:
            fhand.write(line)
        for xx, yy in zip(x_news, y_prop):
            fhand.write('{} {}\n'.format(str(yy), str(int(xx))))
